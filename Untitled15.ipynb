# %%
# !git clone https://github.com/ihababdelkareem/video-summarization
# Out:
# Cloning into 'video-summarization'...
# remote: Total 106 (delta 34), reused 61 (delta 32), pack-reused 38 (from 1)
# Receiving objects: 100% (106/106), 4.61 MiB | 28.78 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# !pip install -r /content/video-summarization/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 36.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 kB 19.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 26.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 86.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# ...

# %%
# %cd /content/video-summarization/
# %ls
# !python /content/src/main.py /content/video-summarization/test.mp4
# Out:
# /content/video-summarization
# 'complete application.png'   kfs/        requirements.txt   temp/      test_3/
# 'keyframe extraction.png'    README.md   src/               temp.m4a   test.mp4
# 3063 frames from test.mp4 read in 4.98 seconds
# Processing Video: test.mp4
# ######################################################
# ##################
# Sampling to 3 FPS
# 29.97002997002997/3 -> 9
# Resizing to 299x299
# Done in 0 Sec
# OpenCV: FFMPEG: tag 0x4745504d/'MPEG' is not supported with codec id 2 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 341 frames from test_3.mp4 read in 0.27 seconds
# 2024-12-17 12:02:01.244289: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
pip install pyclustering
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 23.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyclustering: filename=pyclustering-0.10.1.2-py3-none-any.whl size=2395099 sha256=e9e87216e2e6e59a327646b3660812d8d8ead3a96295e6fb6c606797c45f211b
#   Stored in directory: /root/.cache/pip/wheels/b5/42/97/11eee99f5c1e4fdfc170f0a54f9c9eb195df66edb4cf69f449
# Successfully built pyclustering
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content
# !python -m src.main
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/src/main.py", line 4, in <module>
#     from .utils.inputVideo import InputVideo
# ModuleNotFoundError: No module named 'src.utils'

# %%
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=8b8a0908977b7b74476d38d74a8db6794409c87d1f3c0a6bb3f11676f5688591
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# ...

# %%
# !pip show utils
# Out:
# Name: utils
# Version: 1.0.2
# Summary: A grab-bag of utility functions and objects
# Home-page: http://github.com/haaksmash/pyutils
# Author: Haak Saxberg
# Author-email: haak.erling@gmail.com
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:
